# %% [markdown]
# ## first importent in the create ai based chatbot was workflow

# %%
# !pip install langgraph langsmith
# Out:
# Requirement already satisfied: langgraph in d:\changepond_technology\langgraph\ai_env\lib\site-packages (0.2.70)
# Requirement already satisfied: langsmith in d:\changepond_technology\langgraph\ai_env\lib\site-packages (0.3.8)
# Requirement already satisfied: langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43 in d:\changepond_technology\langgraph\ai_env\lib\site-packages (from langgraph) (0.3.34)
# Requirement already satisfied: langgraph-checkpoint<3.0.0,>=2.0.10 in d:\changepond_technology\langgraph\ai_env\lib\site-packages (from langgraph) (2.0.12)
# Requirement already satisfied: langgraph-sdk<0.2.0,>=0.1.42 in d:\changepond_technology\langgraph\ai_env\lib\site-packages (from langgraph) (0.1.51)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\changepond_technology\langgraph\ai_env\lib\site-packages (from langsmith) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in d:\changepond_technology\langgraph\ai_env\lib\site-packages (from langsmith) (3.10.15)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in d:\changepond_technology\langgraph\ai_env\lib\site-packages (from langsmith) (2.10.6)
# Requirement already satisfied: requests<3,>=2 in d:\changepond_technology\langgraph\ai_env\lib\site-packages (from langsmith) (2.32.3)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in d:\changepond_technology\langgraph\ai_env\lib\site-packages (from langsmith) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in d:\changepond_technology\langgraph\ai_env\lib\site-packages (from langsmith) (0.23.0)
# Requirement already satisfied: anyio in d:\changepond_technology\langgraph\ai_env\lib\site-packages (from httpx<1,>=0.23.0->langsmith) (4.8.0)
# Requirement already satisfied: certifi in d:\changepond_technology\langgraph\ai_env\lib\site-packages (from httpx<1,>=0.23.0->langsmith) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in d:\changepond_technology\langgraph\ai_env\lib\site-packages (from httpx<1,>=0.23.0->langsmith) (1.0.7)
# Requirement already satisfied: idna in d:\changepond_technology\langgraph\ai_env\lib\site-packages (from httpx<1,>=0.23.0->langsmith) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in d:\changepond_technology\langgraph\ai_env\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith) (0.14.0)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in d:\changepond_technology\langgraph\ai_env\lib\site-packages (from langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph) (9.0.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in d:\changepond_technology\langgraph\ai_env\lib\site-packages (from langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in d:\changepond_technology\langgraph\ai_env\lib\site-packages (from langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph) (6.0.2)
# Requirement already satisfied: packaging<25,>=23.2 in d:\changepond_technology\langgraph\ai_env\lib\site-packages (from langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in d:\changepond_technology\langgraph\ai_env\lib\site-packages (from langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph) (4.12.2)
# Requirement already satisfied: msgpack<2.0.0,>=1.1.0 in d:\changepond_technology\langgraph\ai_env\lib\site-packages (from langgraph-checkpoint<3.0.0,>=2.0.10->langgraph) (1.1.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\changepond_technology\langgraph\ai_env\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langsmith) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in d:\changepond_technology\langgraph\ai_env\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langsmith) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\changepond_technology\langgraph\ai_env\lib\site-packages (from requests<3,>=2->langsmith) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\changepond_technology\langgraph\ai_env\lib\site-packages (from requests<3,>=2->langsmith) (2.3.0)
# Requirement already satisfied: jsonpointer>=1.9 in d:\changepond_technology\langgraph\ai_env\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph) (3.0.0)
# Requirement already satisfied: sniffio>=1.1 in d:\changepond_technology\langgraph\ai_env\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith) (1.3.1)
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install langchain langchain_groq langchain_community
# Out:
# Collecting langchain
#   Downloading langchain-0.3.18-py3-none-any.whl.metadata (7.8 kB)
# Collecting langchain_groq
#   Using cached langchain_groq-0.2.4-py3-none-any.whl.metadata (3.0 kB)
# Collecting langchain_community
#   Downloading langchain_community-0.3.17-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.34 in d:\changepond_technology\langgraph\ai_env\lib\site-packages (from langchain) (0.3.34)
# Collecting langchain-text-splitters<1.0.0,>=0.3.6 (from langchain)
#   Downloading langchain_text_splitters-0.3.6-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in d:\changepond_technology\langgraph\ai_env\lib\site-packages (from langchain) (0.3.8)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in d:\changepond_technology\langgraph\ai_env\lib\site-packages (from langchain) (2.10.6)
# Collecting SQLAlchemy<3,>=1.4 (from langchain)
#   Downloading SQLAlchemy-2.0.38-cp312-cp312-win_amd64.whl.metadata (9.9 kB)
# Requirement already satisfied: requests<3,>=2 in d:\changepond_technology\langgraph\ai_env\lib\site-packages (from langchain) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in d:\changepond_technology\langgraph\ai_env\lib\site-packages (from langchain) (6.0.2)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain)
#   Downloading aiohttp-3.11.12-cp312-cp312-win_amd64.whl.metadata (8.0 kB)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in d:\changepond_technology\langgraph\ai_env\lib\site-packages (from langchain) (9.0.0)
# Collecting numpy<3,>=1.26.2 (from langchain)
#   Downloading numpy-2.2.3-cp312-cp312-win_amd64.whl.metadata (60 kB)
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.8 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.8 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.8 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.8 kB ? eta -:--:--
#      ------------------- ------------------ 30.7/60.8 kB 130.4 kB/s eta 0:00:01
#      ------------------------------- ------ 51.2/60.8 kB 174.3 kB/s eta 0:00:01
#      -------------------------------------- 60.8/60.8 kB 215.3 kB/s eta 0:00:00
# Collecting groq<1,>=0.4.1 (from langchain_groq)
#   Downloading groq-0.18.0-py3-none-any.whl.metadata (14 kB)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain_community)
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting pydantic-settings<3.0.0,>=2.4.0 (from langchain_community)
#   Using cached pydantic_settings-2.7.1-py3-none-any.whl.metadata (3.5 kB)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain_community)
#   Using cached httpx_sse-0.4.0-py3-none-any.whl.metadata (9.0 kB)
# Collecting aiohappyeyeballs>=2.3.0 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading aiohappyeyeballs-2.4.6-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Using cached aiosignal-1.3.2-py2.py3-none-any.whl.metadata (3.8 kB)
# Collecting attrs>=17.3.0 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Using cached attrs-25.1.0-py3-none-any.whl.metadata (10 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Using cached frozenlist-1.5.0-cp312-cp312-win_amd64.whl.metadata (14 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Using cached multidict-6.1.0-cp312-cp312-win_amd64.whl.metadata (5.1 kB)
# Collecting propcache>=0.2.0 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Using cached propcache-0.2.1-cp312-cp312-win_amd64.whl.metadata (9.5 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Using cached yarl-1.18.3-cp312-cp312-win_amd64.whl.metadata (71 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain_community)
#   Downloading marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain_community)
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in d:\changepond_technology\langgraph\ai_env\lib\site-packages (from groq<1,>=0.4.1->langchain_groq) (4.8.0)
# Collecting distro<2,>=1.7.0 (from groq<1,>=0.4.1->langchain_groq)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\changepond_technology\langgraph\ai_env\lib\site-packages (from groq<1,>=0.4.1->langchain_groq) (0.28.1)
# Requirement already satisfied: sniffio in d:\changepond_technology\langgraph\ai_env\lib\site-packages (from groq<1,>=0.4.1->langchain_groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in d:\changepond_technology\langgraph\ai_env\lib\site-packages (from groq<1,>=0.4.1->langchain_groq) (4.12.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in d:\changepond_technology\langgraph\ai_env\lib\site-packages (from langchain-core<1.0.0,>=0.3.34->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in d:\changepond_technology\langgraph\ai_env\lib\site-packages (from langchain-core<1.0.0,>=0.3.34->langchain) (24.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in d:\changepond_technology\langgraph\ai_env\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (3.10.15)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in d:\changepond_technology\langgraph\ai_env\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in d:\changepond_technology\langgraph\ai_env\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\changepond_technology\langgraph\ai_env\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in d:\changepond_technology\langgraph\ai_env\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.27.2)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings<3.0.0,>=2.4.0->langchain_community)
#   Using cached python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\changepond_technology\langgraph\ai_env\lib\site-packages (from requests<3,>=2->langchain) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in d:\changepond_technology\langgraph\ai_env\lib\site-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\changepond_technology\langgraph\ai_env\lib\site-packages (from requests<3,>=2->langchain) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\changepond_technology\langgraph\ai_env\lib\site-packages (from requests<3,>=2->langchain) (2025.1.31)
# Collecting greenlet!=0.4.17 (from SQLAlchemy<3,>=1.4->langchain)
#   Using cached greenlet-3.1.1-cp312-cp312-win_amd64.whl.metadata (3.9 kB)
# Requirement already satisfied: httpcore==1.* in d:\changepond_technology\langgraph\ai_env\lib\site-packages (from httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain_groq) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in d:\changepond_technology\langgraph\ai_env\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain_groq) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in d:\changepond_technology\langgraph\ai_env\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.34->langchain) (3.0.0)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community)
#   Using cached mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Downloading langchain-0.3.18-py3-none-any.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    - -------------------------------------- 0.0/1.0 MB 1.3 MB/s eta 0:00:01
#    - -------------------------------------- 0.0/1.0 MB 1.3 MB/s eta 0:00:01
#    - -------------------------------------- 0.0/1.0 MB 388.9 kB/s eta 0:00:03
#    -- ------------------------------------- 0.1/1.0 MB 435.7 kB/s eta 0:00:03
#    --- ------------------------------------ 0.1/1.0 MB 435.7 kB/s eta 0:00:03
#    ---- ----------------------------------- 0.1/1.0 MB 467.6 kB/s eta 0:00:02
#    ---- ----------------------------------- 0.1/1.0 MB 450.6 kB/s eta 0:00:02
#    ------ --------------------------------- 0.2/1.0 MB 435.7 kB/s eta 0:00:02
#    ------ --------------------------------- 0.2/1.0 MB 436.9 kB/s eta 0:00:02
#    ------- -------------------------------- 0.2/1.0 MB 452.9 kB/s eta 0:00:02
#    -------- ------------------------------- 0.2/1.0 MB 458.5 kB/s eta 0:00:02
#    ---------- ----------------------------- 0.3/1.0 MB 462.0 kB/s eta 0:00:02
#    ---------- ----------------------------- 0.3/1.0 MB 462.0 kB/s eta 0:00:02
#    ----------- ---------------------------- 0.3/1.0 MB 453.2 kB/s eta 0:00:02
#    ------------ --------------------------- 0.3/1.0 MB 467.6 kB/s eta 0:00:02
#    -------------- ------------------------- 0.4/1.0 MB 506.0 kB/s eta 0:00:02
#    --------------- ------------------------ 0.4/1.0 MB 505.2 kB/s eta 0:00:02
#    ---------------- ----------------------- 0.4/1.0 MB 513.9 kB/s eta 0:00:02
#    ----------------- ---------------------- 0.5/1.0 MB 521.7 kB/s eta 0:00:02
#    ------------------- -------------------- 0.5/1.0 MB 538.3 kB/s eta 0:00:01
#    -------------------- ------------------- 0.5/1.0 MB 545.8 kB/s eta 0:00:01
#    --------------------- ------------------ 0.6/1.0 MB 560.1 kB/s eta 0:00:01
#    ---------------------- ----------------- 0.6/1.0 MB 544.3 kB/s eta 0:00:01
#    ----------------------- ---------------- 0.6/1.0 MB 567.3 kB/s eta 0:00:01
#    ------------------------- -------------- 0.6/1.0 MB 562.7 kB/s eta 0:00:01
#    -------------------------- ------------- 0.7/1.0 MB 574.4 kB/s eta 0:00:01
#    --------------------------- ------------ 0.7/1.0 MB 569.8 kB/s eta 0:00:01
#    ----------------------------- ---------- 0.7/1.0 MB 582.4 kB/s eta 0:00:01
#    ------------------------------ --------- 0.8/1.0 MB
12.6 MB 1.3 MB/s eta 0:00:03
#    ------------------------------- -------- 9.9/12.6 MB 1.3 MB/s eta 0:00:03
#    ------------------------------- -------- 10.0/12.6 MB 1.3 MB/s eta 0:00:03
#    ------------------------------- -------- 10.0/12.6 MB 1.3 MB/s eta 0:00:03
#    ------------------------------- -------- 10.1/12.6 MB 1.3 MB/s eta 0:00:02
#    -------------------------------- ------- 10.2/12.6 MB 1.3 MB/s eta 0:00:02
#    -------------------------------- ------- 10.2/12.6 MB 1.3 MB/s eta 0:00:02
#    -------------------------------- ------- 10.3/12.6 MB 1.3 MB/s eta 0:00:02
#    -------------------------------- ------- 10.4/12.6 MB 1.3 MB/s eta 0:00:02
#    --------------------------------- ------ 10.4/12.6 MB 1.3 MB/s eta 0:00:02
#    --------------------------------- ------ 10.5/12.6 MB 1.3 MB/s eta 0:00:02
#    --------------------------------- ------ 10.5/12.6 MB 1.3 MB/s eta 0:00:02
#    --------------------------------- ------ 10.5/12.6 MB 1.3 MB/s eta 0:00:02
#    --------------------------------- ------ 10.5/12.6 MB 1.3 MB/s eta 0:00:02
#    --------------------------------- ------ 10.7/12.6 MB 1.3 MB/s eta 0:00:02
#    ---------------------------------- ----- 10.8/12.6 MB 1.3 MB/s eta 0:00:02
#    ---------------------------------- ----- 10.8/12.6 MB 1.3 MB/s eta 0:00:02
#    ---------------------------------- ----- 10.9/12.6 MB 1.3 MB/s eta 0:00:02
#    ---------------------------------- ----- 10.9/12.6 MB 1.3 MB/s eta 0:00:02
#    ---------------------------------- ----- 11.0/12.6 MB 1.3 MB/s eta 0:00:02
#    ---------------------------------- ----- 11.0/12.6 MB 1.3 MB/s eta 0:00:02
#    ----------------------------------- ---- 11.1/12.6 MB 1.3 MB/s eta 0:00:02
#    ----------------------------------- ---- 11.2/12.6 MB 1.4 MB/s eta 0:00:02
#    ----------------------------------- ---- 11.2/12.6 MB 1.4 MB/s eta 0:00:02
#    ----------------------------------- ---- 11.3/12.6 MB 1.4 MB/s eta 0:00:01
#    ------------------------------------ --- 11.4/12.6 MB 1.4 MB/s eta 0:00:01
#    ------------------------------------ --- 11.5/12.6 MB 1.4 MB/s eta 0:00:01
#    ------------------------------------ --- 11.5/12.6 MB 1.4 MB/s eta 0:00:01
#    ------------------------------------ --- 11.6/12.6 MB 1.4 MB/s eta 0:00:01
#    ------------------------------------ --- 11.7/12.6 MB 1.4 MB/s eta 0:00:01
#    ------------------------------------- -- 11.7/12.6 MB 1.4 MB/s eta 0:00:01
#    ------------------------------------- -- 11.8/12.6 MB 1.4 MB/s eta 0:00:01
#    ------------------------------------- -- 11.9/12.6 MB 1.4 MB/s eta 0:00:01
#    ------------------------------------- -- 12.0/12.6 MB 1.4 MB/s eta 0:00:01
#    -------------------------------------- - 12.0/12.6 MB 1.4 MB/s eta 0:00:01
#    -------------------------------------- - 12.1/12.6 MB 1.4 MB/s eta 0:00:01
#    -------------------------------------- - 12.1/12.6 MB 1.4 MB/s eta 0:00:01
#    -------------------------------------- - 12.2/12.6 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------  12.3/12.6 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------  12.4/12.6 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------  12.5/12.6 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.6 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.6 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------- 12.6/12.6 MB 1.4 MB/s eta 0:00:00
# Using cached pydantic_settings-2.7.1-py3-none-any.whl (29 kB)
# Downloading SQLAlchemy-2.0.38-cp312-cp312-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    - -------------------------------------- 0.1/2.1 MB 1.6 MB/s eta 0:00:02
#    -- ------------------------------------- 0.1/2.1 MB 1.7 MB/s eta 0:00:02
#    --- ------------------------------------ 0.2/2.1 MB 1.6 MB/s eta 0:00:02
#    ----- ---------------------------------- 0.3/2.1 MB 1.6 MB/s eta 0:00:02
#    ------ --------------------------------- 0.3/2.1 MB 1.5 MB/s eta 0:00:02
#    ------- -------------------------------- 0.4/2.1 MB 1.5 MB/s eta 0:00:02
#    -------- ------------------------------- 0.5/2.1 MB 1.5 MB/s eta 0:00:02
#    --------- ------------------------------ 0.5/2.1 MB 1.4 MB/s eta 0:00:02
#    ----------- ---------------------------- 0.6/2.1 MB 1.5 MB/s eta 0:00:02
#    ------------ --------------------------- 0.7/2.1 MB 1.5 MB/s eta 0:00:01
#    ------------- -------------------------- 0.7/2.1 MB 1.5 MB/s eta 0:00:01
#    -------------- ------------------------- 0.8/2.1 MB 1.4 MB/s eta 0:00:01
#    --------------- ------------------------ 0.8/2.1 MB 1.4 MB/s eta 0:00:01
#    ----------------- ---------------------- 0.9/2.1 MB 1.4 MB/s eta 0:00:01
#    ----------------- ---------------------- 0.9/2.1 MB 1.4 MB/s eta 0:00:01
#    ------------------- -------------------- 1.0/2.1 MB 1.4 MB/s eta 0:00:01
#    -------------------- ------------------- 1.1/2.1 MB 1.4 MB/s eta 0:00:01
#    --------------------- ------------------ 1.1/2.1 MB 1.3 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.2/2.1 MB 1.3 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.2/2.1 MB 1.3 MB/s eta 0:00:01
#    ------------------------ --------------- 1.3/2.1 MB 1.4 MB/s eta 0:00:01
#    ------------------------- -------------- 1.3/2.1 MB 1.3 MB/s eta 0:00:01
#    -------------------------- ------------- 1.4/2.1 MB 1.3 MB/s eta 0:00:01
#    --------------------------- ------------ 1.5/2.1 MB 1.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.5/2.1 MB 1.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.6/2.1 MB 1.3 MB/s eta 0:00:01
#    ------------------------------ --------- 1.6/2.1 MB 1.3 MB/s eta 0:00:01
#    ------------------------------- -------- 1.7/2.1 MB 1.3 MB/s eta 0:00:01
#    --------------------------------- ------ 1.7/2.1 MB 1.3 MB/s eta 0:00:01
#    --------------------------------- ------ 1.8/2.1 MB 1.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 1.9/2.1 MB 1.3 MB/s eta 0:00:01
#    ------------------------------------ --- 1.9/2.1 MB 1.3 MB/s eta 0:00:01
#    ------------------------------------- -- 2.0/2.1 MB 1.3 MB/s eta 0:00:01
#    -------------------------------------- - 2.0/2.1 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------  2.1/2.1 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 1.3 MB/s eta 0:00:00
# Downloading aiohappyeyeballs-2.4.6-py3-none-any.whl (14 kB)
# Using cached aiosignal-1.3.2-py2.py3-none-any.whl (7.6 kB)
# Using cached attrs-25.1.0-py3-none-any.whl (63 kB)
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Using cached frozenlist-1.5.0-cp312-cp312-win_amd64.whl (51 kB)
# Using cached greenlet-3.1.1-cp312-cp312-win_amd64.whl (299 kB)
# Downloading marshmallow-3.26.1-py3-none-any.whl (50 kB)
#    ---------------------------------------- 0.0/50.9 kB ? eta -:--:--
#    ---------------------------------------- 50.9/50.9 kB 1.3 MB/s eta 0:00:00
# Using cached multidict-6.1.0-cp312-cp312-win_amd64.whl (28 kB)
# Using cached propcache-0.2.1-cp312-cp312-win_amd64.whl (44 kB)
# Using cached python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Using cached yarl-1.18.3-cp312-cp312-win_amd64.whl (90 kB)
# Using cached mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: python-dotenv, propcache, numpy, mypy-extensions, multidict, marshmallow, httpx-sse, greenlet, frozenlist, distro, attrs, aiohappyeyeballs, yarl, typing-inspect, SQLAlchemy, aiosignal, pydantic-settings, groq, dataclasses-json, aiohttp, langchain-text-splitters, langchain_groq, langchain, langchain_community
# Successfully installed SQLAlchemy-2.0.38 aiohappyeyeballs-2.4.6 aiohttp-3.11.12 aiosignal-1.3.2 attrs-25.1.0 dataclasses-json-0.6.7 distro-1.9.0 frozenlist-1.5.0 greenlet-3.1.1 groq-0.18.0 httpx-sse-0.4.0 langchain-0.3.18 langchain-text-splitters-0.3.6 langchain_community-0.3.17 langchain_groq-0.2.4 marshmallow-3.26.1 multidict-6.1.0 mypy-extensions-1.0.0 numpy-2.2.3 propcache-0.2.1 pydantic-settings-2.7.1 python-dotenv-1.0.1 typing-inspect-0.9.0 yarl-1.18.3
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#to load the env file 
# !pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in d:\changepond_technology\langgraph\ai_env\lib\site-packages (1.0.1)
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#import the nessasory api keys
from dotenv import load_dotenv

load_dotenv()


import os
groq_api_key = os.environ['groq_api']
langsmith_api = os.environ['langsmith']
project_name = os.environ['project_name']
# Out:
# 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 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 langgraph_learning

# %%
#set up the langsmith tracking setup

import os
os.environ["LANGCHAIN_API_KEY"] = langsmith_api
os.environ["LANGCHAIN_TRACING_V2"]="true"
os.environ["LANGCHAIN_PROJECT"]= project_name

# %%
#declare the llm 

from langchain_groq import ChatGroq

llm = ChatGroq(groq_api_key=groq_api_key,model_name="llama3-8b-8192")
llm
# Out:
# ChatGroq(client=<groq.resources.chat.completions.Completions object at 0x000001B193264290>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x000001B1932652E0>, model_name='llama3-8b-8192', model_kwargs={}, groq_api_key=SecretStr('**********'))

# %% [markdown]
# ## Start Building Chatbot Using Langgraph

# %%
# nessasory packages for the langgraph was 

from typing import Annotated                          # this was datatype for declare the structure datatype
from typing_extensions import TypedDict               # inside the class we want to specify the Typedict to declare the class was type of dict
from langgraph.graph import START,END,StateGraph      # for here we are using the stategrap for store the message and pass the message one node to another node
from langgraph.graph.message import add_messages      # this add_message was append the message into the class of state

# %%
# declare the class of the state


class Store_message(TypedDict):
    #  # Messages have the type "list". The `add_messages` function
    # in the annotation defines how this state key should be updated
    # (in this case, it appends messages to the list, rather than overwriting them)

    #syntax for declare the message list inside this list was in the type of dict type 
    message:Annotated[list,add_messages]

#create the state by using the stategrap function

graph_builder = StateGraph(Store_message)
graph_builder

# %%
# now create the function that mean create the node here i am takeing the only one node that will call the llm 

def chatbot_small_llm(state:Store_message):     # here state was contan the store_message class
    return{"message":llm.invoke(state["message"])}    # this was invoke the llm using rhe message and store into the store_message function

# %%
#add the node for chatbot_small_llm

graph_builder.add_node("chatbot_small_llm",chatbot_small_llm)
# Out:
# Adding a node to a graph that has already been compiled. This will not be reflected in the compiled graph.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 3
#       1 #add the node for chatbot_small_llm
# ----> 3 graph_builder.add_node("chatbot_small_llm",chatbot_small_llm)
#
# File d:\Changepond_technology\Langgraph\ai_env\Lib\site-packages\langgraph\graph\state.py:350, in StateGraph.add_node(self, node, action, metadata, input, retry)
#     348     raise RuntimeError
#     349 if node in self.nodes:
# --> 350     raise ValueError(f"Node `{node}` already present.")
#     351 if node == END or node == START:
#     352     raise ValueError(f"Node `{node}` is reserved.")
#
# ValueError: Node `chatbot_small_llm` already present.

# %%
# add the ediges in graph

graph_builder.add_edge(START,"chatbot_small_llm")      # this chatbot_small_llm was the funciton name 
graph_builder.add_edge("chatbot_small_llm",END)


# after give the add_node, add_edgies, add_condect etc now we want to compail it


graph = graph_builder.compile()
graph
# Out:
# Adding an edge to a graph that has already been compiled. This will not be reflected in the compiled graph.
# Adding an edge to a graph that has already been compiled. This will not be reflected in the compiled graph.

# %%
# to display the workflow in image

from IPython.display import Image, display
try:
  display(Image(graph.get_graph().draw_mermaid_png()))
except Exception:
  pass

# %% [markdown]
# ## now exicute the code

# %%
while True:
    user_input = input("enter the quary: ")
    if user_input == "b":
        break
    for trash in graph.stream({"message":("user",user_input)}):
        print(trash.values())
        for trash1 in trash.values():
            print(trash1["message"])
            print("assistant", trash1["message"].content)
# Out:
# dict_values([{'message': AIMessage(content="Hi! It's nice to meet you. Is there something I can help you with or would you like to chat?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 25, 'prompt_tokens': 11, 'total_tokens': 36, 'completion_time': 0.020833333, 'prompt_time': 0.001740815, 'queue_time': 0.125292964, 'total_time': 0.022574148}, 'model_name': 'llama3-8b-8192', 'system_fingerprint': 'fp_179b0f92c9', 'finish_reason': 'stop', 'logprobs': None}, id='run-2469725c-646c-4e87-82ea-f12f9839445c-0', usage_metadata={'input_tokens': 11, 'output_tokens': 25, 'total_tokens': 36})}])
# content="Hi! It's nice to meet you. Is there something I can help you with or would you like to chat?" additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 25, 'prompt_tokens': 11, 'total_tokens': 36, 'completion_time': 0.020833333, 'prompt_time': 0.001740815, 'queue_time': 0.125292964, 'total_time': 0.022574148}, 'model_name': 'llama3-8b-8192', 'system_fingerprint': 'fp_179b0f92c9', 'finish_reason': 'stop', 'logprobs': None} id='run-2469725c-646c-4e87-82ea-f12f9839445c-0' usage_metadata={'input_tokens': 11, 'output_tokens': 25, 'total_tokens': 36}
# assistant Hi! It's nice to meet you. Is there something I can help you with or would you like to chat?
# dict_values([{'message': AIMessage(content="Hi! It's nice to meet you. Is there something I can help you with or would you like to chat?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 25, 'prompt_tokens': 11, 'total_tokens': 36, 'completion_time': 0.020833333, 'prompt_time': 0.001758985, 'queue_time': 0.854835275, 'total_time': 0.022592318}, 'model_name': 'llama3-8b-8192', 'system_fingerprint': 'fp_179b0f92c9', 'finish_reason': 'stop', 'logprobs': None}, id='run-85e64df7-b213-4b80-9a28-93d255394b00-0', usage_metadata={'input_tokens': 11, 'output_tokens': 25, 'total_tokens': 36})}])
# content="Hi! It's nice to meet you. Is there something I can help you with or would you like to chat?" additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 25, 'prompt_tokens': 11, 'total_tokens': 36, 'completion_time': 0.020833333, 'prompt_time': 0.001758985, 'queue_time': 0.854835275, 'total_time': 0.022592318}, 'model_name': 'llama3-8b-8192', 'system_fingerprint': 'fp_179b0f92c9', 'finish_reason': 'stop', 'logprobs': None} id='run-85e64df7-b213-4b80-9a28-93d255394b00-0' usage_metadata={'input_tokens': 11, 'output_tokens': 25, 'total_tokens': 36}
# assistant Hi! It's nice to meet you. Is there something I can help you with or would you like to chat?
# dict_values([{'message': AIMessage(content='"Gen AI" is a term used to describe a hypothetical future generation of artificial intelligence (AI) systems that are capable of human-like intelligence, creativity, and problem-solving abilities. The term "Gen AI" is often used to refer to the next generation of AI systems that will surpass the capabilities of current AI systems in various fields.\n\nThe term "Gen AI" is often associated with the concept of Artificial General Intelligence (AGI), which refers to a hypothetical AI system that possesses the ability to understand, learn, and apply knowledge across a wide range of tasks, similar to human intelligence. AGI is often considered the holy grail of AI research, as it would allow AI systems to perform any intellectual task that a human can.\n\nSome of the key characteristics of Gen AI/AGI include:\n\n1. Human-like intelligence: Gen AI systems would be able to learn, reason, and apply knowledge in a way that is similar to human intelligence.\n2. Creativity: Gen AI systems would be able to generate novel and innovative ideas, similar to human creativity.\n3. Problem-solving abilities: Gen AI systems would be able to solve complex problems and make decisions independently, similar to human problem-solving abilities.\n4. Self-awareness: Gen AI systems would be able to understand their own existence and have a sense of self-awareness.\n5. Ability to learn from experience: Gen AI systems would be able to learn from their experiences and adapt to new situations.\n\nThe development of Gen AI/AGI is still in its early stages, and it is unclear when or if such systems will be developed. However, researchers are actively working on developing AI systems that can learn, reason, and apply knowledge in complex environments, and some experts believe that we may see the development of AGI within the next few decades.\n\nIt\'s worth noting that the development of Gen AI/AGI raises many ethical and philosophical questions, such as:\n\n1. Job displacement: Will Gen AI systems replace human jobs?\n2. Bias and fairness: Will Gen AI systems be biased towards certain groups or individuals?\n3. Accountability: Who will be responsible for the actions of Gen AI systems?\n4. Human values: Will Gen AI systems be able to understand and respect human values and ethics?\n\nOverall, the development of Gen AI/AGI is a complex and challenging task that requires significant advances in areas such as machine learning, natural language processing, computer vision, and cognitive architectures.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 491, 'prompt_tokens': 16, 'total_tokens': 507, 'completion_time': 0.409166667, 'prompt_time': 0.001783605, 'queue_time': 0.020025291, 'total_time': 0.410950272}, 'model_name': 'llama3-8b-8192', 'system_fingerprint': 'fp_179b0f92c9', 'finish_reason': 'stop', 'logprobs': None}, id='run-90e0ae85-f009-4cad-8527-b6d65d8c7148-0', usage_metadata={'input_tokens': 16, 'output_tokens': 491, 'total_tokens': 507})}])
# content='"Gen AI" is a term used to describe a hypothetical future generation of artificial intelligence (AI) systems that are capable of human-like intelligence, creativity, and problem-solving abilities. The term "Gen AI" is often used to refer to the next generation of AI systems that will surpass the capabilities of current AI systems in various fields.\n\nThe term "Gen AI" is often associated with the concept of Artificial General Intelligence (AGI), which refers to a hypothetical AI system that possesses the ability to understand, learn, and apply knowledge across a wide range of tasks, similar to human intelligence. AGI is often considered the holy grail of AI research, as it would allow AI systems to perform any intellectual task that a human can.\n\nSome of the key characteristics of Gen AI/AGI include:\n\n1. Human-like intelligence: Gen AI systems would be able to learn, reason, and apply knowledge in a way that is similar to human intelligence.\n2. Creativity: Gen AI systems would be able to generate novel and innovative ideas, similar to human creativity.\n3. Problem-solving abilities: Gen AI systems would be able to solve complex problems and make decisions independently, similar to human problem-solving abilities.\n4. Self-awareness: Gen AI systems would be able to understand their own existence and have a sense of self-awareness.\n5. Ability to learn from experience: Gen AI systems would be able to learn from their experiences and adapt to new situations.\n\nThe development of Gen AI/AGI is still in its early stages, and it is unclear when or if such systems will be developed. However, researchers are actively working on developing AI systems that can learn, reason, and apply knowledge in complex environments, and some experts believe that we may see the development of AGI within the next few decades.\n\nIt\'s worth noting that the development of Gen AI/AGI raises many ethical and philosophical questions, such as:\n\n1. Job displacement: Will Gen AI systems replace human jobs?\n2. Bias and fairness: Will Gen AI systems be biased towards certain groups or individuals?\n3. Accountability: Who will be responsible for the actions of Gen AI systems?\n4. Human values: Will Gen AI systems be able to understand and respect human values and ethics?\n\nOverall, the development of Gen AI/AGI is a complex and challenging task that requires significant advances in areas such as machine learning, natural language processing, computer vision, and cognitive architectures.' additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 491, 'prompt_tokens': 16, 'total_tokens': 507, 'completion_time': 0.409166667, 'prompt_time': 0.001783605, 'queue_time': 0.020025291, 'total_time': 0.410950272}, 'model_name': 'llama3-8b-8192', 'system_fingerprint': 'fp_179b0f92c9', 'finish_reason': 'stop', 'logprobs': None} id='run-90e0ae85-f009-4cad-8527-b6d65d8c7148-0' usage_metadata={'input_tokens': 16, 'output_tokens': 491, 'total_tokens': 507}
# assistant "Gen AI" is a term used to describe a hypothetical future generation of artificial intelligence (AI) systems that are capable of human-like intelligence, creativity, and problem-solving abilities. The term "Gen AI" is often used to refer to the next generation of AI systems that will surpass the capabilities of current AI systems in various fields.
#
# The term "Gen AI" is often associated with the concept of Artificial General Intelligence (AGI), which refers to a hypothetical AI system that possesses the ability to understand, learn, and apply knowledge across a wide range of tasks, similar to human intelligence. AGI is often considered the holy grail of AI research, as it would allow AI systems to perform any intellectual task that a human can.
#
# Some of the key characteristics of Gen AI/AGI include:
#
# 1. Human-like intelligence: Gen AI systems would be able to learn, reason, and apply knowledge in a way that is similar to human intelligence.
# 2. Creativity: Gen AI systems would be able to generate novel and innovative ideas, similar to human creativity.
# 3. Problem-solving abilities: Gen AI systems would be able to solve complex problems and make decisions independently, similar to human problem-solving abilities.
# 4. Self-awareness: Gen AI systems would be able to understand their own existence and have a sense of self-awareness.
# 5. Ability to learn from experience: Gen AI systems would be able to learn from their experiences and adapt to new situations.
#
# The development of Gen AI/AGI is still in its early stages, and it is unclear when or if such systems will be developed. However, researchers are actively working on developing AI systems that can learn, reason, and apply knowledge in complex environments, and some experts believe that we may see the development of AGI within the next few decades.
#
# It's worth noting that the development of Gen AI/AGI raises many ethical and philosophical questions, such as:
#
# 1. Job displacement: Will Gen AI systems replace human jobs?
# 2. Bias and fairness: Will Gen AI systems be biased towards certain groups or individuals?
# 3. Accountability: Who will be responsible for the actions of Gen AI systems?
# 4. Human values: Will Gen AI systems be able to understand and respect human values and ethics?
#
# Overall, the development of Gen AI/AGI is a complex and challenging task that requires significant advances in areas such as machine learning, natural language processing, computer vision, and cognitive architectures.
# dict_values([{'message': AIMessage(content='"Gen AI" is a term used to describe Artificial Intelligence (AI) that is specifically designed to mimic human-like intelligence, creativity, and decision-making abilities. The term is often used to distinguish this type of AI from more narrow or specialized forms of AI, such as rule-based systems or machine learning models.\n\nThe concept of Gen AI is often associated with the idea of "general" or "general-purpose" intelligence, which refers to the ability of a machine to learn, reason, and apply knowledge across a wide range of tasks and domains, without being limited to a specific domain or set of rules.\n\nGen AI is often characterized by its ability to:\n\n1. Learn and adapt: Gen AI systems can learn from experience, adapt to new situations, and refine their performance over time.\n2. Reason and infer: Gen AI systems can reason about abstract concepts, make inferences, and draw conclusions based on incomplete or uncertain information.\n3. Create and generate: Gen AI systems can generate new ideas, create art, music, or writing, and even develop new products or services.\n4. Interact and communicate: Gen AI systems can interact with humans in a naturalistic way, using language, gestures, or other forms of communication.\n5. Understand and empathize: Gen AI systems can understand human emotions, intentions, and motivations, and respond in a way that is empathetic and compassionate.\n\nSome examples of Gen AI applications include:\n\n1. Virtual assistants: Gen AI-powered virtual assistants like Siri, Google Assistant, or Alexa can understand natural language, learn from user behavior, and adapt to new situations.\n2. Robotics: Gen AI-powered robots like Sophia or Pepper can learn from experience, adapt to new environments, and interact with humans in a more natural way.\n3. Autonomous vehicles: Gen AI-powered autonomous vehicles can learn from experience, adapt to new situations, and make decisions in real-time.\n4. Healthcare: Gen AI-powered healthcare systems can analyze medical data, identify patterns, and make predictions or recommendations for diagnosis and treatment.\n\nWhile Gen AI has the potential to revolutionize many industries and aspects of our lives, it also raises important ethical and societal concerns, such as job displacement, bias in decision-making, and the potential for misuse.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 450, 'prompt_tokens': 16, 'total_tokens': 466, 'completion_time': 0.375, 'prompt_time': 0.002555982, 'queue_time': 0.27398217799999997, 'total_time': 0.377555982}, 'model_name': 'llama3-8b-8192', 'system_fingerprint': 'fp_179b0f92c9', 'finish_reason': 'stop', 'logprobs': None}, id='run-d89db50d-1eee-4bac-915c-13730b74ca9d-0', usage_metadata={'input_tokens': 16, 'output_tokens': 450, 'total_tokens': 466})}])
# content='"Gen AI" is a term used to describe Artificial Intelligence (AI) that is specifically designed to mimic human-like intelligence, creativity, and decision-making abilities. The term is often used to distinguish this type of AI from more narrow or specialized forms of AI, such as rule-based systems or machine learning models.\n\nThe concept of Gen AI is often associated with the idea of "general" or "general-purpose" intelligence, which refers to the ability of a machine to learn, reason, and apply knowledge across a wide range of tasks and domains, without being limited to a specific domain or set of rules.\n\nGen AI is often characterized by its ability to:\n\n1. Learn and adapt: Gen AI systems can learn from experience, adapt to new situations, and refine their performance over time.\n2. Reason and infer: Gen AI systems can reason about abstract concepts, make inferences, and draw conclusions based on incomplete or uncertain information.\n3. Create and generate: Gen AI systems can generate new ideas, create art, music, or writing, and even develop new products or services.\n4. Interact and communicate: Gen AI systems can interact with humans in a naturalistic way, using language, gestures, or other forms of communication.\n5. Understand and empathize: Gen AI systems can understand human emotions, intentions, and motivations, and respond in a way that is empathetic and compassionate.\n\nSome examples of Gen AI applications include:\n\n1. Virtual assistants: Gen AI-powered virtual assistants like Siri, Google Assistant, or Alexa can understand natural language, learn from user behavior, and adapt to new situations.\n2. Robotics: Gen AI-powered robots like Sophia or Pepper can learn from experience, adapt to new environments, and interact with humans in a more natural way.\n3. Autonomous vehicles: Gen AI-powered autonomous vehicles can learn from experience, adapt to new situations, and make decisions in real-time.\n4. Healthcare: Gen AI-powered healthcare systems can analyze medical data, identify patterns, and make predictions or recommendations for diagnosis and treatment.\n\nWhile Gen AI has the potential to revolutionize many industries and aspects of our lives, it also raises important ethical and societal concerns, such as job displacement, bias in decision-making, and the potential for misuse.' additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 450, 'prompt_tokens': 16, 'total_tokens': 466, 'completion_time': 0.375, 'prompt_time': 0.002555982, 'queue_time': 0.27398217799999997, 'total_time': 0.377555982}, 'model_name': 'llama3-8b-8192', 'system_fingerprint': 'fp_179b0f92c9', 'finish_reason': 'stop', 'logprobs': None} id='run-d89db50d-1eee-4bac-915c-13730b74ca9d-0' usage_metadata={'input_tokens': 16, 'output_tokens': 450, 'total_tokens': 466}
# assistant "Gen AI" is a term used to describe Artificial Intelligence (AI) that is specifically designed to mimic human-like intelligence, creativity, and decision-making abilities. The term is often used to distinguish this type of AI from more narrow or specialized forms of AI, such as rule-based systems or machine learning models.
#
# The concept of Gen AI is often associated with the idea of "general" or "general-purpose" intelligence, which refers to the ability of a machine to learn, reason, and apply knowledge across a wide range of tasks and domains, without being limited to a specific domain or set of rules.
#
# Gen AI is often characterized by its ability to:
#
# 1. Learn and adapt: Gen AI systems can learn from experience, adapt to new situations, and refine their performance over time.
# 2. Reason and infer: Gen AI systems can reason about abstract concepts, make inferences, and draw conclusions based on incomplete or uncertain information.
# 3. Create and generate: Gen AI systems can generate new ideas, create art, music, or writing, and even develop new products or services.
# 4. Interact and communicate: Gen AI systems can interact with humans in a naturalistic way, using language, gestures, or other forms of communication.
# 5. Understand and empathize: Gen AI systems can understand human emotions, intentions, and motivations, and respond in a way that is empathetic and compassionate.
#
# Some examples of Gen AI applications include:
#
# 1. Virtual assistants: Gen AI-powered virtual assistants like Siri, Google Assistant, or Alexa can understand natural language, learn from user behavior, and adapt to new situations.
# 2. Robotics: Gen AI-powered robots like Sophia or Pepper can learn from experience, adapt to new environments, and interact with humans in a more natural way.
# 3. Autonomous vehicles: Gen AI-powered autonomous vehicles can learn from experience, adapt to new situations, and make decisions in real-time.
# 4. Healthcare: Gen AI-powered healthcare systems can analyze medical data, identify patterns, and make predictions or recommendations for diagnosis and treatment.
#
# While Gen AI has the potential to revolutionize many industries and aspects of our lives, it also raises important ethical and societal concerns, such as job displacement, bias in decision-making, and the potential for misuse.
